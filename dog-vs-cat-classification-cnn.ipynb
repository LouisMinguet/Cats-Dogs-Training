# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import os 
import zipfile
from tqdm import tqdm
from glob import glob
from shutil import copy, move

# %% [markdown]
# ## Data Preparation

# %%
zipfile_dir = '../input/dogs-vs-cats/train.zip'
train_dir = zipfile.ZipFile(zipfile_dir, 'r')
train_dir.extractall()

zipfile_dir = '../input/dogs-vs-cats/test1.zip'
test_dir = zipfile.ZipFile(zipfile_dir, 'r')
test_dir.extractall()

# %%
TRAIN_DIR = './train'
TEST_DIR = './test1'

train_set = os.listdir(TRAIN_DIR)
test_set = os.listdir(TEST_DIR)

print('#train images: %s'%len(train_set))
print('#test images: %s'%len(test_set))
print(train_set[:5])
print(test_set[:5])
# Out:
# #train images: 25000
# #test images: 12500
# ['dog.384.jpg', 'dog.11037.jpg', 'dog.2780.jpg', 'dog.9082.jpg', 'cat.10408.jpg']
# ['7332.jpg', '11163.jpg', '9992.jpg', '8741.jpg', '2157.jpg']

# %%
dog_train_dir = './training/dog'
dog_val_dir = './validation/dog'
cat_train_dir = './training/cat'
cat_val_dir = './validation/cat'

file_dirs = [dog_train_dir, dog_val_dir, cat_train_dir, cat_val_dir]

for dir in file_dirs:
    os.makedirs(dir,exist_ok = True)

# %%
all_dogs = glob('./train/dog*jpg')
all_cats = glob('./train/cat*jpg')

print(len(all_dogs))
print(len(all_cats))
# Out:
# 12500
# 12500

# %%
from sklearn.model_selection import train_test_split

dogs_train, dogs_test = train_test_split(all_dogs, test_size=0.1, shuffle=True,random_state = 100)
cats_train, cats_test = train_test_split(all_cats, test_size=0.1, shuffle=True,random_state = 100)

# %%
for name in tqdm(dogs_train):
  copy(name , os.path.join(dog_train_dir , name.split('/')[-1]))
for name in tqdm(cats_train):
  copy(name , os.path.join(cat_train_dir , name.split('/')[-1]))
  
for name in tqdm(dogs_test):
  copy(name , os.path.join(dog_val_dir , name.split('/')[-1]))
for name in tqdm(cats_test):
  copy(name , os.path.join(cat_val_dir , name.split('/')[-1]))
# Out:
# 100%|██████████| 11250/11250 [00:02<00:00, 5441.57it/s]
# 100%|██████████| 11250/11250 [00:02<00:00, 4149.47it/s]
# 100%|██████████| 1250/1250 [00:00<00:00, 5481.47it/s]
# 100%|██████████| 1250/1250 [00:00<00:00, 5740.17it/s]

# %%
print(len(os.listdir(dog_train_dir)))
print(len(os.listdir(cat_train_dir)))
print(len(os.listdir(dog_val_dir)))
print(len(os.listdir(cat_val_dir)))
# Out:
# 11250
# 11250
# 1250
# 1250

# %% [markdown]
# ## Data Preprocessing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

TRAINING_DIR = './training'
train_datagen = ImageDataGenerator(rescale=1 / 255)
train_generator = train_datagen.flow_from_directory(
    TRAINING_DIR,
    batch_size=64,
    class_mode='binary',
    target_size=(150, 150)
)

VALIDATION_DIR = './validation'
validation_datagen = ImageDataGenerator(rescale=1/255)
validation_generator = validation_datagen.flow_from_directory(
    VALIDATION_DIR,
    batch_size = 64,
    class_mode = 'binary',
    target_size = (150, 150)
)
# Out:
# Found 22500 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.

# %% [markdown]
# ## Model Creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, MaxPool2D, Flatten, Dropout

model = Sequential()
model.add(Conv2D(64, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal',input_shape=(150, 150, 3)))
model.add(Conv2D(64, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Conv2D(256, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Conv2D(256, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Conv2D(512, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Conv2D(512, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(units=1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 150, 150, 64)      1792
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 150, 150, 64)      36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 75, 75, 64)        0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 75, 75, 128)       73856
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 75, 75, 128)       147584
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 75, 75, 128)       147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 37, 37, 256)       295168
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 37, 37, 256)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 37, 37, 256)       590080
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 37, 37, 256)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 37, 37, 256)       590080
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 18, 18, 256)       0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 18, 18, 256)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 18, 18, 512)       1180160
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 18, 18, 512)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 18, 18, 512)       2359808
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 18, 18, 512)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 18, 18, 512)       2359808
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 9, 9, 512)         0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 9, 9, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 41472)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              42468352
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 52,351,425
# Trainable params: 52,351,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
check_point_path = './best.h5'
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath = check_point_path,
    monitor = 'val_accuracy',
    save_weights_only=False,
    save_best_only=True,
    verbose=1
)

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(0.0005,decay=1e-5),
             loss = 'binary_crossentropy',
             metrics = ['acc'])

# %%
print('Num Params : ',model.count_params())
model_history = model.fit(
    train_generator,
    epochs=10,
    verbose=1,
    callbacks = [model_checkpoint],
    validation_data=validation_generator
)
# Out:
# Num Params :  52351425
# Epoch 1/10
# 352/352 [==============================] - 93s 261ms/step - loss: 4.2445 - acc: 0.4930 - val_loss: 0.6932 - val_acc: 0.5000
# Epoch 2/10
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6928 - acc: 0.5065 - val_loss: 0.6932 - val_acc: 0.5000
# Epoch 3/10
# 352/352 [==============================] - 92s 261ms/step - loss: 0.6931 - acc: 0.5072 - val_loss: 0.6936 - val_acc: 0.5000
# Epoch 4/10
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6936 - acc: 0.4899 - val_loss: 0.6932 - val_acc: 0.5000
# Epoch 5/10
# 352/352 [==============================] - 91s 258ms/step - loss: 0.6908 - acc: 0.5233 - val_loss: 0.6917 - val_acc: 0.5172
# Epoch 6/10
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6764 - acc: 0.5619 - val_loss: 1.1320 - val_acc: 0.5000
# Epoch 7/10
# 352/352 [==============================] - 91s 259ms/step - loss: 0.6675 - acc: 0.5922 - val_loss: 0.6788 - val_acc: 0.5580
# Epoch 8/10
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6015 - acc: 0.6653 - val_loss: 0.5944 - val_acc: 0.6580
# Epoch 9/10
# 352/352 [==============================] - 92s 260ms/step - loss: 0.5678 - acc: 0.6999 - val_loss: 0.6149 - val_acc: 0.6400
# Epoch 10/10
# 352/352 [==============================] - 91s 259ms/step - loss: 0.5497 - acc: 0.7165 - val_loss: 0.5257 - val_acc: 0.7044

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Plotting Loss and Accuracy

# %%
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=model_history.history['acc']
val_acc=model_history.history['val_acc']
loss=model_history.history['loss']
val_loss=model_history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(["Training Accuracy","Validation Accuracy"])
plt.show()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.title('Training and validation loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(["Training Loss","Validation Loss"])
plt.show()

# Desired output. Charts with training and validation metrics.

# %%
test_file = os.listdir("./test1")
test_df = pd.DataFrame({
    'filename': test_file
})
test_df
# Out:
#         filename
# 0       7332.jpg
# 1      11163.jpg
# 2       9992.jpg
# 3       8741.jpg
# 4       2157.jpg
# ...          ...
# 12495   8974.jpg
# 12496  10254.jpg
# 12497   5951.jpg
# 12498  12431.jpg
# 12499   6749.jpg
#
# [12500 rows x 1 columns]

# %%
TESTING_DIR = './test1'
test_generator = train_datagen.flow_from_dataframe(
    test_df,
    directory = TESTING_DIR,
    x_col='filename',
    y_col=None,
    batch_size=64,
    target_size=(150, 150),
    shuffle = False,
    class_mode = None
)
# Out:
# Found 12500 validated image filenames.

# %%
test_generator.reset()
y_pred = model.predict(test_generator)

# %% [markdown]
# To see the class mapping of dogs and cats, we have to see class_indices from training dataset

# %%
train_generator.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %% [markdown]
# Let's make labels

# %%
y_pred_classification = np.where(y_pred > 0.5, 1, 0)
y_pred_classification
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]])

# %% [markdown]
# Seeing some results

# %%
test_generator.reset()
test_images = test_generator[0][:9]

fig, ax = plt.subplots(3,3)
fig.set_size_inches(10,10)
for i, img in enumerate(test_images):
    ax[i//3][i%3].imshow(img)
    if y_pred_classification[i]==1:
        label = 'Dog'
    else:
        label = 'Cat'
    ax[i//3][i%3].set_title(label)

# %% [markdown]
# Visualizing first 9 filters

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f566c3afdd0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5672099d50>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f5655a6c4d0>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f5655a68610>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f567319b850>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5672099350>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5655abae10>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f566c16d410>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f567306db10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5655abd250>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f567318ff90>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f567306d490>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f56730544d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f566c3affd0>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f567305cad0>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f5655a6b910>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f5673042310>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f5673047d50>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f566c188250>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f567303d210>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f567305cf90>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f5672ff8a50>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f5673001e90>,
#  <tensorflow.python.keras.layers.core.Flatten at 0x7f5655a6b110>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f5672ff8550>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f5672ff3250>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f5672fdf150>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f5672ff86d0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f5672fdf810>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f566c3c4310>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f567300f490>]

# %%
first_conv = model.layers[0]
output_layer1 = first_conv(test_images)[4]

print(output_layer1.shape)
fig, ax = plt.subplots(3,3)
fig.set_size_inches(10,10)
for i in range(9):
  ax[i//3][i%3].imshow(output_layer1[:,:,i])
# Out:
# (150, 150, 64)

# %% [markdown]
# ## Submition

# %%
submission = pd.read_csv('../input/dogs-vs-cats/sampleSubmission.csv')
submission['label'] = y_pred_classification
submission
# Out:
#           id  label
# 0          1      0
# 1          2      0
# 2          3      1
# 3          4      0
# 4          5      1
# ...      ...    ...
# 12495  12496      0
# 12496  12497      1
# 12497  12498      0
# 12498  12499      0
# 12499  12500      0
#
# [12500 rows x 2 columns]

# %%
submission.to_csv('submission.csv',index='False')
